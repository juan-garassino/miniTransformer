# %% [markdown]
# #CLONING

# %%
# !git clone https://github.com/juan-garassino/miniTransformer.git
# Out:
# Cloning into 'miniTransformer'...
# remote: Enumerating objects: 323, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 323 (delta 1), reused 6 (delta 0), pack-reused 302
# Receiving objects: 100% (323/323), 141.74 MiB | 40.91 MiB/s, done.
# Resolving deltas: 100% (118/118), done.

# %% [markdown]
# #INSTALLING

# %%
# %cd /content/miniTransformer
# Out:
# /content/miniTransformer

# %%
pip install --no-deps -e .
# Out:
# Obtaining file:///content/miniTransformer
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for miniTransformer
# ...

# %% [markdown]
# #ENVIROMENTAL VARIABLES

# %%
import os

# Retrieve the HOME environment variable
home_dir = os.environ['HOME']

# Construct your project root path
project_root = os.path.join(home_dir, '..', 'content', 'miniTransformer')

# Set the PROJECT_ROOT environment variable in the notebook's environment
# %env PROJECT_ROOT={project_root}
# Out:
# env: PROJECT_ROOT=/root/../content/miniTransformer

# %% [markdown]
# #EXECUTION

# %%
# !python -m miniTransformer.preprocessing.train_tokenizer
# Out:
# merge 1/256: (97, 32) -> 256 (b'a ') had 30697 occurrences
# merge 2/256: (101, 32) -> 257 (b'e ') had 26292 occurrences
# merge 3/256: (111, 32) -> 258 (b'o ') had 23220 occurrences
# merge 4/256: (115, 32) -> 259 (b's ') had 16187 occurrences
# merge 5/256: (101, 110) -> 260 (b'en') had 16169 occurrences
# merge 6/256: (44, 32) -> 261 (b', ') had 12528 occurrences
# merge 7/256: (101, 114) -> 262 (b'er') had 12087 occurrences
# merge 8/256: (97, 110) -> 263 (b'an') had 9235 occurrences
# merge 9/256: (97, 114) -> 264 (b'ar') had 9207 occurrences
# merge 10/256: (101, 115) -> 265 (b'es') had 9172 occurrences
# merge 11/256: (113, 117) -> 266 (b'qu') had 8457 occurrences
# merge 12/256: (111, 110) -> 267 (b'on') had 8216 occurrences
# merge 13/256: (100, 257) -> 268 (b'de ') had 7875 occurrences
# merge 14/256: (10, 10) -> 269 (b'\n\n') had 7583 occurrences
# merge 15/256: (111, 114) -> 270 (b'or') had 6991 occurrences
# merge 16/256: (97, 108) -> 271 (b'al') had 6745 occurrences
# ...

# %%
# !pip install colorama
# Out:
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# minitransformer 1.0 requires black, which is not installed.
# minitransformer 1.0 requires coverage, which is not installed.
# minitransformer 1.0 requires flake8, which is not installed.
# minitransformer 1.0 requires memoized-property, which is not installed.
# minitransformer 1.0 requires mlflow, which is not installed.
# minitransformer 1.0 requires s3fs, which is not installed.
# minitransformer 1.0 requires tiktoken, which is not installed.
# minitransformer 1.0 requires twine, which is not installed.
# minitransformer 1.0 requires yapf, which is not installed.
# ...

# %%
	# !python -m miniTransformer.main \
	--batch_size 64 \
	--block_size 256 \
	--max_iters 20000 \
	--eval_interval 100 \
	--learning_rate 1e-3 \
	--device cpu \
	--eval_iters 10 \
	--n_embd 384 \
	--n_head 6 \
	--n_layer 6 \
	--dropout 0.2 \
	--colab 1 \
	--data_dir miniTransformer/data \
	--name input.txt \
	--checkpoint_dir miniTransformer/results/checkpoints \
	--save_interval 100 \
  --colab 1 \
	--plots_dir miniTransformer/results/heatmaps \
	--heatmap_interval 100
# Out:
# ✅ Loading the data...
#
# ✅ Length of dataset in characters: 2111683
#
# 🔀 Creating character mappings...
#
# 🔢 Creating encoder and decoder functions...
#
# 🔤 Encoding the input text...
#
# 🔄 Creating training and validation data splits...
#
# 🔄 Instantiating the BigramLanguageModel...
#
# ✅ BigramLanguageModel Initialized...
#
# 🔢 Number of Attention Heads: 6
#
# 🔢 Embedding Size: 384
#
# 🔢 Block Size: 256
#
# 🔄 Moved the model to the device
#
# ✅ Creating a PyTorch optimizer...
#
# ✅ Starting the main training loop...
# 10.813537 M parameters
#
# ✅ Checkpoint directory was created
#
# ✅ Saved checkpoint at step 0
#
# ✅ Sampling a batch of data...
#
# ✅ Updating the model parameters...
#
# ✅ Evaluating model loss...

# %%
# !python -m miniTransformer.main \
# 	--batch_size 64 \
# 	--block_size 256 \
# 	--max_iters 20000 \
# 	--eval_interval 100 \
# 	--learning_rate 1e-3 \
# 	--device cpu \
# 	--eval_iters 10 \
# 	--n_embd 384 \
# 	--n_head 6 \
# 	--n_layer 6 \
# 	--dropout 0.2 \
# 	--data_dir data \
# 	--name input.txt \
# 	--checkpoint_dir miniTransformer/results/checkpoints \
# 	--save_interval 100 \
# 	--plots_dir miniTransformer/heatmaps \
# 	--heatmap_interval 100 \
# 	--colab 1 \
# 	--checkpoint checkpoint_18400.pt \
# 	--n_of_char 2000
# Out:
# ✅ Loading the data...
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/miniTransformer/miniTransformer/main.py", line 156, in <module>
#     train(
#   File "/content/miniTransformer/miniTransformer/training/train.py", line 85, in train
#     text = load_data(path)  # , name)
#   File "/content/miniTransformer/miniTransformer/preprocessing/sourcing/sourcing.py", line 16, in load_data
#     files = os.listdir(path)
# FileNotFoundError: [Errno 2] No such file or directory: '/root/../content/data'
